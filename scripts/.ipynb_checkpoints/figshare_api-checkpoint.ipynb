# %% [markdown]
# # Stream large relational data from figshare

# %%
'''
Figshare API convenience functions.
Modified from code provided by Daniel Gavrila
Requires Python 3.6+ due to the use of f-strings.
Logging is now implemented.
'''

# %%
import hashlib
import logging
import json
import os
import requests
from requests.exceptions import HTTPError

# %% [markdown]
# ### Set variables
# Change the values as appropriate

# %%
BASE_URL = 'https://api.figshare.com/v2/{endpoint}'
TOKEN = 'd8ad9b040c0c6b28b147ecc356e769374a8d0a4b628c832a1627e4eaa6c3ec4ace829420cc91908c2e60d4df657649d6d4995bf247a6fca2e16d4e4bc92f3a86'
CHUNK_SIZE = 10485760 #about 10MB
COLLECTION_ID = 6076908

# %% [markdown]
# ### Define the functions

# %%
## Namespace

class Namespace:
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

# %%
# define functions to make api request

## methods

def printerr(String, *args, **kwargs):
    print(String, sys.stderr, *args, **kwargs)

def logthis(msg,logger=None):
    if logger:
        logger.info(msg)
    else:
        print(msg)

def raw_issue_request(method, url, data=None, binary=False, logger=None):
    if data is not None and not binary:
        data = json.dumps(data)
    response = requests.request(method, url, data=data)
    try:
        response.raise_for_status()
        try:
            data = json.loads(response.content)
        except ValueError:
            data = response.reason
    except HTTPError as error:
        if logger:
            logger.error(f'Caught an HTTPError: {error.response.status_code}')
            logger.error('Body:\n' + response.reason)
        else:
            print('Caught an HTTPError: {}'.format(error.response.status_code))
            print('Body:\n', response.reason)
        raise

    return data

def issue_request(method, endpoint, logger=None, *args, **kwargs):
    return raw_issue_request(method, BASE_URL.format(endpoint=endpoint), logger=logger, *args, **kwargs)

def get_collection_articles(collection_id=COLLECTION_ID, page=1, page_size=100, logger=None):
    endpoint = f'collections/{collection_id}/articles'
    logthis(f'Listing articles for {collection_id}.')
    result = True
    output = []
    while result:
        endpoint_curr = f'{endpoint}?page={page}&page_size={page_size}'
        result = issue_request('GET', endpoint_curr, logger=logger)
        if result:
            output += result
            page += 1
    return output

def get_article_info(article_id, logger=None):
    endpoint = f'articles/{article_id}'
    logthis(f'Getting info for article {article_id}.')
    result = issue_request('GET', endpoint, logger=logger)
    return result

# %% [markdown]
# # move this to other script!

# %%
import requests
import pandas as pd
from tqdm import tqdm  # Import the tqdm module

# %%
get_collection_articles()
# Out:
# Listing articles for 6076908.
# [{'id': 21896802,
#   'title': 'SciSciNet_Authors_Gender',
#   'doi': '10.6084/m9.figshare.21896802.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/21896802',
#   'published_date': '2023-05-18T14:42:20Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/21896802',
#   'url_public_api': 'https://api.figshare.com/v2/articles/21896802',
#   'url_private_html': 'https://figshare.com/account/articles/21896802',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Authors_Gender/21896802',
#   'timeline': {'posted': '2023-05-18T14:42:20',
#    'firstOnline': '2023-05-18T14:42:20'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220093,
#   'title': 'SciSciNet_Fields',
#   'doi': '10.6084/m9.figshare.20220093.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220093',
#   'published_date': '2023-05-18T14:42:20Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220093',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220093',
#   'url_private_html': 'https://figshare.com/account/articles/20220093',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Fields/20220093',
#   'timeline': {'posted': '2023-05-18T14:42:20',
#    'firstOnline': '2023-05-18T14:42:20'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 21896799,
#   'title': 'SciSciNet_Papers',
#   'doi': '10.6084/m9.figshare.21896799.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/21896799',
#   'published_date': '2023-05-18T14:42:20Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/21896799',
#   'url_public_api': 'https://api.figshare.com/v2/articles/21896799',
#   'url_private_html': 'https://figshare.com/account/articles/21896799',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Papers/21896799',
#   'timeline': {'posted': '2023-05-18T14:42:20',
#    'firstOnline': '2023-05-18T14:42:20'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220081,
#   'title': 'SciSciNet_Link_Patents',
#   'doi': '10.6084/m9.figshare.20220081.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220081',
#   'published_date': '2023-05-18T14:42:19Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220081',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220081',
#   'url_private_html': 'https://figshare.com/account/articles/20220081',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Link_Patents/20220081',
#   'timeline': {'posted': '2023-05-18T14:42:19',
#    'firstOnline': '2023-05-18T14:42:19'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220090,
#   'title': 'SciSciNet_Authors',
#   'doi': '10.6084/m9.figshare.20220090.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220090',
#   'published_date': '2023-05-18T14:42:19Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220090',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220090',
#   'url_private_html': 'https://figshare.com/account/articles/20220090',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Authors/20220090',
#   'timeline': {'posted': '2023-05-18T14:42:19',
#    'firstOnline': '2023-05-18T14:42:19'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220084,
#   'title': 'SciSciNet_Link_Twitter',
#   'doi': '10.6084/m9.figshare.20220084.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220084',
#   'published_date': '2023-05-18T14:42:19Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220084',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220084',
#   'url_private_html': 'https://figshare.com/account/articles/20220084',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Link_Twitter/20220084',
#   'timeline': {'posted': '2023-05-18T14:42:19',
#    'firstOnline': '2023-05-18T14:42:19'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220078,
#   'title': 'SciSciNet_NSF_Metadata',
#   'doi': '10.6084/m9.figshare.20220078.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220078',
#   'published_date': '2023-05-18T14:42:19Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220078',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220078',
#   'url_private_html': 'https://figshare.com/account/articles/20220078',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_NSF_Metadata/20220078',
#   'timeline': {'posted': '2023-05-18T14:42:19',
#    'firstOnline': '2023-05-18T14:42:19'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220087,
#   'title': 'SciSciNet_PaperFields',
#   'doi': '10.6084/m9.figshare.20220087.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220087',
#   'published_date': '2023-05-18T14:42:19Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220087',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220087',
#   'url_private_html': 'https://figshare.com/account/articles/20220087',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_PaperFields/20220087',
#   'timeline': {'posted': '2023-05-18T14:42:19',
#    'firstOnline': '2023-05-18T14:42:19'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220072,
#   'title': 'SciSciNet_Papers',
#   'doi': '10.6084/m9.figshare.20220072.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220072',
#   'published_date': '2023-05-18T14:42:18Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220072',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220072',
#   'url_private_html': 'https://figshare.com/account/articles/20220072',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Papers/20220072',
#   'timeline': {'posted': '2023-05-18T14:42:18',
#    'firstOnline': '2023-05-18T14:42:18'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220066,
#   'title': 'SciSciNet_Twitter_Metadata',
#   'doi': '10.6084/m9.figshare.20220066.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220066',
#   'published_date': '2023-05-18T14:42:18Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220066',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220066',
#   'url_private_html': 'https://figshare.com/account/articles/20220066',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Twitter_Metadata/20220066',
#   'timeline': {'posted': '2023-05-18T14:42:18',
#    'firstOnline': '2023-05-18T14:42:18'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220075,
#   'title': 'SciSciNet_Newsfeed_Metadata',
#   'doi': '10.6084/m9.figshare.20220075.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220075',
#   'published_date': '2023-05-18T14:42:18Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220075',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220075',
#   'url_private_html': 'https://figshare.com/account/articles/20220075',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Newsfeed_Metadata/20220075',
#   'timeline': {'posted': '2023-05-18T14:42:18',
#    'firstOnline': '2023-05-18T14:42:18'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220069,
#   'title': 'SciSciNet_PaperAuthorAffiliations',
#   'doi': '10.6084/m9.figshare.20220069.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220069',
#   'published_date': '2023-05-18T14:42:18Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220069',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220069',
#   'url_private_html': 'https://figshare.com/account/articles/20220069',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_PaperAuthorAffiliations/20220069',
#   'timeline': {'posted': '2023-05-18T14:42:18',
#    'firstOnline': '2023-05-18T14:42:18'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220054,
#   'title': 'SciSciNet_Journals',
#   'doi': '10.6084/m9.figshare.20220054.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220054',
#   'published_date': '2023-05-18T14:42:17Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220054',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220054',
#   'url_private_html': 'https://figshare.com/account/articles/20220054',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Journals/20220054',
#   'timeline': {'posted': '2023-05-18T14:42:17',
#    'firstOnline': '2023-05-18T14:42:17'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220063,
#   'title': 'SciSciNet_Link_NIH',
#   'doi': '10.6084/m9.figshare.20220063.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220063',
#   'published_date': '2023-05-18T14:42:17Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220063',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220063',
#   'url_private_html': 'https://figshare.com/account/articles/20220063',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Link_NIH/20220063',
#   'timeline': {'posted': '2023-05-18T14:42:17',
#    'firstOnline': '2023-05-18T14:42:17'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220057,
#   'title': 'SciSciNet_Affiliations',
#   'doi': '10.6084/m9.figshare.20220057.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220057',
#   'published_date': '2023-05-18T14:42:17Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220057',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220057',
#   'url_private_html': 'https://figshare.com/account/articles/20220057',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Affiliations/20220057',
#   'timeline': {'posted': '2023-05-18T14:42:17',
#    'firstOnline': '2023-05-18T14:42:17'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220051,
#   'title': 'SciSciNet_Link_ClinicalTrials',
#   'doi': '10.6084/m9.figshare.20220051.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220051',
#   'published_date': '2023-05-18T14:42:17Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220051',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220051',
#   'url_private_html': 'https://figshare.com/account/articles/20220051',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Link_ClinicalTrials/20220051',
#   'timeline': {'posted': '2023-05-18T14:42:17',
#    'firstOnline': '2023-05-18T14:42:17'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220060,
#   'title': 'SciSciNet_Link_Newsfeed',
#   'doi': '10.6084/m9.figshare.20220060.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220060',
#   'published_date': '2023-05-18T14:42:17Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220060',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220060',
#   'url_private_html': 'https://figshare.com/account/articles/20220060',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Link_Newsfeed/20220060',
#   'timeline': {'posted': '2023-05-18T14:42:17',
#    'firstOnline': '2023-05-18T14:42:17'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220033,
#   'title': 'SciSciNet_PaperReferences',
#   'doi': '10.6084/m9.figshare.20220033.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220033',
#   'published_date': '2023-05-18T14:42:16Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220033',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220033',
#   'url_private_html': 'https://figshare.com/account/articles/20220033',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_PaperReferences/20220033',
#   'timeline': {'posted': '2023-05-18T14:42:16',
#    'firstOnline': '2023-05-18T14:42:16'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220045,
#   'title': 'SciSciNet_ConferenceSeries',
#   'doi': '10.6084/m9.figshare.20220045.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220045',
#   'published_date': '2023-05-18T14:42:16Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220045',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220045',
#   'url_private_html': 'https://figshare.com/account/articles/20220045',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_ConferenceSeries/20220045',
#   'timeline': {'posted': '2023-05-18T14:42:16',
#    'firstOnline': '2023-05-18T14:42:16'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220039,
#   'title': 'SciSciNet_PaperDetails',
#   'doi': '10.6084/m9.figshare.20220039.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220039',
#   'published_date': '2023-05-18T14:42:16Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220039',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220039',
#   'url_private_html': 'https://figshare.com/account/articles/20220039',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_PaperDetails/20220039',
#   'timeline': {'posted': '2023-05-18T14:42:16',
#    'firstOnline': '2023-05-18T14:42:16'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220048,
#   'title': 'SciSciNet_Link_NSF',
#   'doi': '10.6084/m9.figshare.20220048.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220048',
#   'published_date': '2023-05-18T14:42:16Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220048',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220048',
#   'url_private_html': 'https://figshare.com/account/articles/20220048',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Link_NSF/20220048',
#   'timeline': {'posted': '2023-05-18T14:42:16',
#    'firstOnline': '2023-05-18T14:42:16'},
#   'resource_title': None,
#   'resource_doi': None},
#  {'id': 20220042,
#   'title': 'SciSciNet_Link_NobelLaureates',
#   'doi': '10.6084/m9.figshare.20220042.v1',
#   'handle': '',
#   'url': 'https://api.figshare.com/v2/articles/20220042',
#   'published_date': '2023-05-18T14:42:16Z',
#   'thumb': '',
#   'defined_type': 3,
#   'defined_type_name': 'dataset',
#   'group_id': 2826,
#   'url_private_api': 'https://api.figshare.com/v2/account/articles/20220042',
#   'url_public_api': 'https://api.figshare.com/v2/articles/20220042',
#   'url_private_html': 'https://figshare.com/account/articles/20220042',
#   'url_public_html': 'https://springernature.figshare.com/articles/dataset/SciSciNet_Link_NobelLaureates/20220042',
#   'timeline': {'posted': '2023-05-18T14:42:16',
#    'firstOnline': '2023-05-18T14:42:16'},
#   'resource_title': None,
#   'resource_doi': None}]

# %%
# access download url 
url = get_article_info(20220093).get('files')[0]['download_url']
print(url)
# Out:
# Getting info for article 20220093.
# https://ndownloader.figshare.com/files/36222114

# %%
def download_data(article_id):
    url = get_article_info(article_id).get('files')[0]['download_url']
    response = requests.get(url, stream=True)  # Use stream=True to download content incrementally
    
    try:
        # Get the total content length from the response headers
        total_size = int(response.headers.get('content-length', 0))
        
        # Create a tqdm progress bar
        progress_bar = tqdm(total=total_size, unit='B', unit_scale=True)
        
        # Open a file to write the downloaded content
        with open('downloaded_data.tsv', 'wb') as file:
            for chunk in response.iter_content(chunk_size=1024):
                if chunk:
                    file.write(chunk)
                    progress_bar.update(len(chunk))  # Update the progress bar

        # Close the progress bar
        progress_bar.close()
        
        # Read the downloaded TSV file into a DataFrame
        df = pd.read_csv('downloaded_data.tsv', sep='\t')
        return df
    
    except Exception as e:
        print("An error occurred:", e)
        return None

# %%
df = download_data(20220093)
print(df)
# Out:
# Getting info for article 20220093.
# 100%|██████████████████████████████████████| 9.32k/9.32k [00:00<00:00, 5.32MB/s]
#        FieldID               Field_Name Field_Type
# 0      3079626  Quantum electrodynamics        Sub
# 1     37914503     Mathematical physics        Sub
# 2    159047783                 Virology        Sub
# 3     70410870      Clinical psychology        Sub
# 4    187212893               Pediatrics        Sub
# ..         ...                      ...        ...
# 306   70721500    Computational biology        Sub
# 307   42360764     Chemical engineering        Sub
# 308  178550888  Business administration        Sub
# 309   13736549   Industrial engineering        Sub
# 310   47768531    Development economics        Sub
#
# [311 rows x 3 columns]

# %%
search_term = 'science'

filtered_df = df[df['Field_Name'].str.contains(search_term, case=False)]

# %%
print(filtered_df)
# Out:
#         FieldID                    Field_Name Field_Type
# 12     31903555                  Food science        Sub
# 39    148383697              Regional science        Sub
# 49      1965285                 Earth science        Sub
# 59     37621935          Agricultural science        Sub
# 87    192562407             Materials science        Top
# 93     36289849                Social science        Sub
# 118   161191863               Library science        Sub
# 124   140793950                Animal science        Sub
# 137      459310         Computational science        Sub
# 152    41008148              Computer science        Top
# 157   169760540                  Neuroscience        Sub
# 160   162118730             Actuarial science        Sub
# 165   188147891             Cognitive science        Sub
# 167   159390177                  Soil science        Sub
# 171    17744445             Political science        Top
# 177   539667460            Management science        Sub
# 197    80444323  Theoretical computer science        Sub
# 199    39432304         Environmental science        Top
# 228  2522767166                  Data science        Sub
# 272   126348684               Polymer science        Sub
# 284    91586092          Atmospheric sciences        Sub

# %% [markdown]
# CONTINUE THIS HERE LATER
